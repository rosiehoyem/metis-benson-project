# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

# %%
df = pd.read_csv('data/subway_tract_intersect_0.csv')
df1 = pd.read_csv('data/turnstile_160507 copy.txt')

# %%
df.head()
# Out:
#    OBJECTID_1  Join_Count  TARGET_FID  \
# 0           1           1           1
# 1           2           1           2
# 2           3           1           3
# 3           4           1           4
# 4           5           1           5
#
#                                                notes  \
# 0  4 nights, 6-all times, 6 Express-weekdays AM s...
# 1  4 nights, 6-all times, 6 Express-weekdays AM s...
# 2                              1-all times, 2-nights
# 3           4-nights, 3-all other times, 2-all times
# 4                        4-nights, 3-all other times
#
#                                  url              name  objectid  \
# 0  http://web.mta.info/nyct/service/          Astor Pl       1.0
# 1  http://web.mta.info/nyct/service/          Canal St       2.0
# 2  http://web.mta.info/nyct/service/           50th St       3.0
# 3  http://web.mta.info/nyct/service/         Bergen St       4.0
# 4  http://web.mta.info/nyct/service/  Pennsylvania Ave       5.0
#
# ...

# %%
capitalizer = lambda x: x.upper()
df['name'] = df['name'].apply(capitalizer)
df.head()
# Out:
#    OBJECTID_1  Join_Count  TARGET_FID  \
# 0           1           1           1
# 1           2           1           2
# 2           3           1           3
# 3           4           1           4
# 4           5           1           5
#
#                                                notes  \
# 0  4 nights, 6-all times, 6 Express-weekdays AM s...
# 1  4 nights, 6-all times, 6 Express-weekdays AM s...
# 2                              1-all times, 2-nights
# 3           4-nights, 3-all other times, 2-all times
# 4                        4-nights, 3-all other times
#
#                                  url              name  objectid  \
# 0  http://web.mta.info/nyct/service/          ASTOR PL       1.0
# 1  http://web.mta.info/nyct/service/          CANAL ST       2.0
# 2  http://web.mta.info/nyct/service/           50TH ST       3.0
# 3  http://web.mta.info/nyct/service/         BERGEN ST       4.0
# 4  http://web.mta.info/nyct/service/  PENNSYLVANIA AVE       5.0
#
# ...

# %%
df1.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  04/30/2016  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  5639941
# 1  REGULAR  5639991
# 2  REGULAR  5640014
# 3  REGULAR  5640158
# 4  REGULAR  5640454
#
#    EXITS
# 0                                            1909983
# 1                                            1909993
# 2                                            1910024
# 3                                            1910134
# 4                                            1910197

# %%
df1.shape
# Out:
# (194466, 11)

# %%
pd.merge(df, df1, how='inner', left_on='name', right_on='STATION')
# Out:
#        OBJECTID_1  Join_Count  TARGET_FID  \
# 0               1           1           1
# 1               1           1           1
# 2               1           1           1
# 3               1           1           1
# 4               1           1           1
# 5               1           1           1
# 6               1           1           1
# 7               1           1           1
# 8               1           1           1
# 9               1           1           1
# 10              1           1           1
# 11              1           1           1
# 12              1           1           1
# 13              1           1           1
# 14              1           1           1
# 15              1           1           1
# 16              1           1           1
# 17              1           1           1
# 18              1           1           1
# 19              1           1           1
# 20              1           1           1
# ...

# %%
df.name.value_counts()
# Out:
# CANAL ST                          5
# 23RD ST                           5
# FULTON ST                         5
# 96TH ST                           4
# 125TH ST                          4
# 86TH ST                           4
# TIMES SQ - 42ND ST                4
# 103RD ST                          3
# ATLANTIC AV - BARCLAY'S CENTER    3
# 14TH ST                           3
# UNION SQ - 14TH ST                3
# GRAND CENTRAL - 42ND ST           3
# CHAMBERS ST                       3
# VAN SICLEN AVE                    3
# BROADWAY JUNCTION                 3
# 28TH ST                           3
# 72ND ST                           3
# 7TH AVE                           3
# 116TH ST                          3
# 111TH ST                          3
# HALSEY ST                         2
# ROCKAWAY AVE                      2
# MYRTLE - WYCKOFF AVES             2
# 34TH ST - PENN STATION            2
# BERGEN ST                         2
# DEKALB AVE                        2
# ...

# %%
df1.STATION.value_counts()
# Out:
# 34 ST-PENN STA     4957
# FULTON ST          4102
# 23 ST              3005
# GRD CNTRL-42 ST    2609
# CANAL ST           2477
# 34 ST-HERALD SQ    2331
# CHAMBERS ST        2267
# 86 ST              2204
# 42 ST-PORT AUTH    2198
# TIMES SQ-42 ST     2149
# 59 ST              2147
# WALL ST            2110
# ATL AV-BARCLAY     2025
# 125 ST             1819
# 14 ST              1804
# 59 ST COLUMBUS     1721
# CHURCH AV          1596
# 14 ST-UNION SQ     1592
# 50 ST              1570
# 161/YANKEE STAD    1562
# 28 ST              1554
# 96 ST              1553
# 47-50 STS ROCK     1541
# METS-WILLETS PT    1530
# JAY ST-METROTEC    1507
# LEXINGTON AV/53    1343
# CORTLANDT ST       1311
# BOWLING GREEN      1218
# BOROUGH HALL       1152
# FLUSHING-MAIN      1150
#                    ...
# AVENUE X            126
# KINGSTON AV         126
# NEREID AV           126
# ALABAMA AV          126
# VAN SICLEN AVE      126
# HARLEM 148 ST       126
# MORRIS PARK         126
# ...

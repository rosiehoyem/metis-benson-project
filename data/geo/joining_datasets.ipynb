# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
stations = pd.read_csv('subway_station_tracts.csv')
stem_women = pd.read_csv('stem_women.csv')

df = pd.merge(stations, stem_women, on='BoroCT2010')

# %%
df
# Out:
#      ﻿OBJECTID_1  Join_Count  TARGET_FID  \
# 0              1           1           1
# 1            401           1         401
# 2              2           1           2
# 3            417           1         417
# 4            435           1         435
# 5            467           1         467
# 6              3           1           3
# 7            347           1         347
# 8            348           1         348
# 9              4           1           4
# 10             5           1           5
# 11             6           1           6
# 12           267           1         267
# 13             7           1           7
# 14             8           1           8
# 15             9           1           9
# 16            54           1          54
# 17            10           1          10
# 18           307           1         307
# 19            11           1          11
# 20           370           1         370
# 21           432           1         432
# ...

# %%
df.plot.bar(x='BoroCT2010', y='stem_women');

# %%
df_sorted = df.sort_values('stem_women', ascending=False)

# %%
df_sorted.plot.bar(x='BoroCT2010', y='stem_women');

# %%
import seaborn as sns

# %%
df_sorted.head(100)
# Out:
#      ﻿OBJECTID_1  Join_Count  TARGET_FID  \
# 376          352           1         352
# 124           86           1          86
# 470          471           1         471
# 132          200           1         200
# 131           92           1          92
# 207          166           1         166
# 400          376           1         376
# 381          413           1         413
# 380          402           1         402
# 379          360           1         360
# 382          427           1         427
# 205          162           1         162
# 437          420           1         420
# 438          428           1         428
# 439          430           1         430
# 137           95           1          95
# 238          203           1         203
# 239          444           1         444
# 436          429           1         429
# 433          422           1         422
# 435          426           1         426
# 432          419           1         419
# ...
